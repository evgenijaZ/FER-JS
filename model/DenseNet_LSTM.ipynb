# %% [markdown]
# <a href="https://colab.research.google.com/github/evgenijaZ/FER-JS/blob/model_notebooks/model/DenseNet_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# !pip install pandas
# !pip install opencv_python
# !pip install keras
# !pip install tensorflow
# !pip install h5py
# !pip install tensorflow-gpu
# !pip install pydot
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: opencv_python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv_python) (1.19.5)
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.4.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras) (1.19.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras) (3.13)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py->keras) (1.5.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.5.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.12)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.5.0.dev2021032900)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.34.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.12.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow) (0.4.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow) (56.1.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow) (1.30.0)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow) (1.5.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2.10)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow) (4.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.2.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.5->tensorflow) (3.4.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.4.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5; python_version == "3.7" in /usr/local/lib/python3.7/dist-packages (from h5py) (1.19.5)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)
# Collecting tensorflow-gpu
#   Downloading https://files.pythonhosted.org/packages/1d/a2/5ccf0a418eb22e0a2ae9edc1e7f5456d0a4b8b49524572897564b4030a9b/tensorflow_gpu-2.5.0-cp37-cp37m-manylinux2010_x86_64.whl (454.3MB)
#      |████████████████████████████████| 454.3MB 38kB/s
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.34.1)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.5.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.12.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.36.2)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.12.4)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.1.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.12)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.19.5)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.1.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.1.2)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.5.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (3.7.4.3)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow-gpu) (2.5.0.dev2021032900)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.9.2->tensorflow-gpu) (56.1.0)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow-gpu) (1.5.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (1.30.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (0.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow-gpu) (2020.12.5)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow-gpu) (4.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow-gpu) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.5->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow-gpu) (3.1.0)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-2.5.0
# Requirement already satisfied: pydot in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from pydot) (2.4.7)

# %% [markdown]
# # Import dataset from Kaggle

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2020.12.5)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)

# %% [markdown]
# Upload Kagge API key to download data

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-516111fa-0bc0-4832-bd88-6a33d7a560c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-516111fa-0bc0-4832-bd88-6a33d7a560c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 72 bytes

# %%
# !kaggle datasets download -d gauravsharma99/ck48-5-emotions
# Out:
# Downloading ck48-5-emotions.zip to /content
#   0% 0.00/1.39M [00:00<?, ?B/s]
# 100% 1.39M/1.39M [00:00<00:00, 94.0MB/s]

# %%
# !unzip -n -q ck48-5-emotions.zip

# %% [markdown]
# # Prepare data

# %%
import cv2
import numpy as np
import matplotlib
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.utils import to_categorical

# %%
import os
from collections import defaultdict

INPUT_PATH = "CK+48/"
for dir_ in os.listdir(INPUT_PATH):
    count = 0
    for f in os.listdir(INPUT_PATH + dir_ + "/"):
        count += 1
    print(f"{dir_} has {count} number of images")
# Out:
# surprise has 249 number of images
# fear has 75 number of images
# happy has 207 number of images
# sadness has 84 number of images
# anger has 135 number of images

# %%
TOP_EMOTIONS = ["surprise", "happy", "anger", "sadness", "fear"]

# %%
data = defaultdict(str)
for dir_ in os.listdir(INPUT_PATH):
    if dir_ in TOP_EMOTIONS:
        data[dir_] = defaultdict(list)
        for f in os.listdir(INPUT_PATH + dir_ + "/"):
            sub = f.split("_")[0]
            data[dir_][sub].append(f)

# %%
def preprocess_list(x):
    return int((x.split("_")[2]).split(".")[0])


def preprocess_dict(x):
    res = list(np.argsort(list(map(preprocess_list, x))))
    return [x[i] for i in res]


def image_to_array(x, path):
    arr = np.empty(shape=(3, 48, 48))
    for i, f in enumerate(x):
        img = cv2.imread(path + f, 0)
        arr[i] = img
    return arr

# %%
for emotion in data:
    data[emotion] = dict((k, preprocess_dict(v)) for k, v in data[emotion].items())
    data[emotion] = dict((k, image_to_array(v, path=INPUT_PATH + emotion + "/")) for k, v in data[emotion].items())

# %%
for k, v in data.items():
    print(f"{k} has {len(v)} samples")
# Out:
# surprise has 83 samples
# fear has 25 samples
# happy has 69 samples
# sadness has 28 samples
# anger has 45 samples

# %%
def prepare_emotion_set(emotion_name):
    em_set = np.stack(data[emotion_name].values(), axis=0)
    return em_set.reshape(*em_set.shape, 1)


surprise = prepare_emotion_set("surprise")
happy = prepare_emotion_set("happy")
anger = prepare_emotion_set("anger")
sadness = prepare_emotion_set("sadness")
fear = prepare_emotion_set("fear")

for emotion in TOP_EMOTIONS:
    temp = np.stack(data[emotion].values(), axis=0)
    temp = temp.reshape(*temp.shape, 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2822: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if self.run_code(code, result):

# %%
label_emotion_mapper = {0: "surprise", 1: "happy", 2: "anger", 3: "sadness", 4: "fear"}


def split_data():
    X = np.concatenate((surprise, happy, anger, sadness, fear))
    y = np.concatenate(
        (np.array([0] * 83), np.array([1] * 69), np.array([2] * 45), np.array([3] * 28), np.array([4] * 25)))
    y = to_categorical(y)
    print(X.shape, y.shape)  # (250, 3, 48, 48, 1), (250, 5)
    X_train, X_valid, y_train, y_valid = train_test_split(
        X,
        y,
        train_size=0.7,
        stratify=y,
        shuffle=True,
        random_state=42
    )
    return X_train, X_valid, y_train, y_valid


X_train, X_valid, y_train, y_valid = split_data()

print(X_train.shape, X_valid.shape) # (175, 3, 48, 48, 1), (75, 3, 48, 48, 1)
# Out:
# (250, 3, 48, 48, 1) (250, 5)
# (175, 3, 48, 48, 1) (75, 3, 48, 48, 1)

# %% [markdown]
# Image normalization

# %%
def normalize(x):
    return 2 * (x / 255. - 0.5)


X_train = normalize(X_train)
X_valid = normalize(X_valid)

# %% [markdown]
# # Build Dense Net to exctract features from images

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import MaxPooling2D, GlobalMaxPool2D
from tensorflow.python.keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, Concatenate, BatchNormalization
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, AveragePooling2D, LSTM, TimeDistributed
from tensorflow.keras.regularizers import l2


def build_densenet(input_shape, dense_blocks=3, dense_layers=-1, growth_rate=12, dropout_rate=None,
                   bottleneck=False, compression=1.0, weight_decay=1e-4, depth=40, batch_norm=True):
    if compression <= 0.0 or compression > 1.0:
        raise Exception(
            'Compression have to be a value between 0.0 and 1.0. If you set compression to 1.0 it will be turn off.')

    if type(dense_layers) is list:
        if len(dense_layers) != dense_blocks:
            raise AssertionError('Number of dense blocks have to be same length to specified layers')
    elif dense_layers == -1:
        if bottleneck:
            dense_layers = (depth - (dense_blocks + 1)) / dense_blocks // 2
        else:
            dense_layers = (depth - (dense_blocks + 1)) // dense_blocks
        dense_layers = [int(dense_layers) for _ in range(dense_blocks)]
    else:
        dense_layers = [int(dense_layers) for _ in range(dense_blocks)]

    Input_image = Input(shape=input_shape)
    # Input_coordinate = Input(shape=(4,))
    nb_channels = growth_rate * 2

    print('Creating DenseNet')
    print('#############################################')
    print('Dense blocks: %s' % dense_blocks)
    print('Layers per dense block: %s' % dense_layers)
    print('#############################################')

    # Initial convolution layer
    x = Conv2D(nb_channels, (3, 3), padding='same', strides=(1, 1),
               use_bias=False, kernel_regularizer=l2(weight_decay))(Input_image)

    # Building dense blocks
    for block in range(dense_blocks):

        # Add dense block
        x, nb_channels = dense_block(x, dense_layers[block], nb_channels, growth_rate, dropout_rate, bottleneck,
                                     weight_decay, batch_norm)

        if block < dense_blocks - 1:  # if it's not the last dense block
            # Add transition_block
            x = transition_layer(x, nb_channels, dropout_rate, compression, weight_decay, batch_norm)
            nb_channels = int(nb_channels * compression)
    if batch_norm:
        x = BatchNormalization(gamma_regularizer=l2(weight_decay), beta_regularizer=l2(weight_decay))(x)
    x = Activation('elu')(x)
    flattenlayer = GlobalAveragePooling2D()(x)

    # concatinated_layer= Concatenate()([flattenlayer,Input_coordinate])
    model = Model(inputs=Input_image, outputs=flattenlayer)

    return model

# %%
def dense_block(x, nb_layers, nb_channels, growth_rate, dropout_rate=None, bottleneck=False, weight_decay=1e-4,
                batch_norm=True):
    x_list = [x]
    for i in range(nb_layers):
        cb = convolution_block(x, growth_rate, dropout_rate, bottleneck, weight_decay, batch_norm)
        x_list.append(cb)
        x = Concatenate(axis=-1)(x_list)
        nb_channels += growth_rate
    return x, nb_channels

# %%
def convolution_block(x, nb_channels, dropout_rate=None, bottleneck=False, weight_decay=1e-4, batch_norm=True):
    # Bottleneck
    if bottleneck:
        bottleneckWidth = 4
        if batch_norm:
            x = BatchNormalization(gamma_regularizer=l2(weight_decay), beta_regularizer=l2(weight_decay))(x)
        x = Activation('elu')(x)
        x = Conv2D(nb_channels * bottleneckWidth, (1, 1), use_bias=False, kernel_regularizer=l2(weight_decay))(x)
        # Dropout
        if dropout_rate:
            x = Dropout(dropout_rate)(x)

    # (BN-eLU-Conv)
    if batch_norm:
        x = BatchNormalization(gamma_regularizer=l2(weight_decay), beta_regularizer=l2(weight_decay))(x)
    x = Activation('elu')(x)
    x = Conv2D(nb_channels, (3, 3), padding='same', use_bias=False, kernel_regularizer=l2(weight_decay))(x)

    # Dropout
    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    return x

# %%
def transition_layer(x, nb_channels, dropout_rate=None, compression=1.0, weight_decay=1e-4, batch_norm=True):
    if batch_norm:
        x = BatchNormalization(gamma_regularizer=l2(weight_decay), beta_regularizer=l2(weight_decay))(x)
    x = Activation('elu')(x)
    x = Conv2D(int(nb_channels * compression), (1, 1), padding='same',
               use_bias=False, kernel_regularizer=l2(weight_decay))(x)

    # Adding dropout
    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    x = AveragePooling2D((2, 2), strides=(2, 2))(x)
    return x

# %% [markdown]
# # Build LSTM

# %%
def memory_model(input_shape, num_class, show_arch=True):
    # base_network = build_dcnn(input_shape[1:], show_arch=False)
    base_network = build_densenet(input_shape[1:], dense_blocks=5, dense_layers=-1, growth_rate=8, dropout_rate=0.2,
                                  bottleneck=False, compression=1.0, weight_decay=1e-4, depth=40, batch_norm=True)
    # keras.utils.plot_model(base_network, to_file='densenet_model.png', show_shapes=True)

    model = Sequential(name="convolutional_Bidrectional_LSTM")

    model.add(TimeDistributed(base_network, input_shape=input_shape, name="time_distributed"))

    model.add(Bidirectional(LSTM(128, return_sequences=True, name="bidirect_lstm_1")))
    model.add(Dropout(.35, name="dropout_lstm_1"))
    model.add(Bidirectional(LSTM(64, return_sequences=False, name="bidirect_lstm_2")))
    model.add(Dropout(.45, name="dropout_lstm_2"))

    model.add(Dense(128, activation='elu', kernel_initializer='he_normal', name='dense_1'))
    model.add(BatchNormalization(name='batchnorm_lstm_1'))
    model.add(Dropout(.7, name="dropout_lstm_3"))

    model.add(Dense(num_class, activation='softmax', name='out_layer'))

    if show_arch:
        model.summary()

    return model

# %% [markdown]
# # Callbacks

# %% [markdown]
# Scheduler

# %%
lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.8,
    patience=7,
    min_lr=1e-7,
    verbose=1,
)

# %% [markdown]
# CSV logger

# %%
dataset_name = "ck+48"
log_file_path = dataset_name + '_emotion_training.log'
csv_logger = CSVLogger(log_file_path, append=False)

# %% [markdown]
# Model checkpoint

# %%
base_path = "content\\"
trained_models_path = base_path + dataset_name + 'lstm'
model_names = trained_models_path + '.{epoch:02d}-{val_loss:.2f}.hdf5'  # if error "acc" in 1 line ... don't confuse check entire block since fit() generates a inner loop
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1, save_best_only=True, save_weights_only=True)

# %% [markdown]
# Early stopping

# %%
early_stop = EarlyStopping('val_loss', patience=100)

# %% [markdown]
# Convolution matrix

# %%
# import io
# import itertools
# import sklearn.metrics

# from tensorflow import keras
# from tensorflow import summary
# from datetime import datetime



# def plot_confusion_matrix(cm, class_names):
#     """
#     Returns a matplotlib figure containing the plotted confusion matrix.

#     Args:
#        cm (array, shape = [n, n]): a confusion matrix of integer classes
#        class_names (array, shape = [n]): String names of the integer classes
#     """

#     figure = matplotlib.pyplot.figure(figsize=(8, 8))
#     matplotlib.pyplot.imshow(cm, interpolation='nearest', cmap=matplotlib.pyplot.cm.Blues)
#     matplotlib.pyplot.title("Confusion matrix")
#     matplotlib.pyplot.colorbar()
#     tick_marks = np.arange(len(class_names))
#     matplotlib.pyplot.xticks(tick_marks, class_names, rotation=45)
#     matplotlib.pyplot.yticks(tick_marks, class_names)

#     # Normalize the confusion matrix.
#     cm = np.around(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis], decimals=2)

#     # Use white text if squares are dark; otherwise black.
#     threshold = cm.max() / 2.

#     for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
#         color = "white" if cm[i, j] > threshold else "black"
#         matplotlib.pyplot.text(j, i, cm[i, j], horizontalalignment="center", color=color)

#     matplotlib.pyplot.tight_layout()
#     matplotlib.pyplot.ylabel('True label')
#     matplotlib.pyplot.xlabel('Predicted label')
#     return figure


# # Create log directory
# logdir = "logs/image/" + datetime.now().strftime("%Y%m%d-%H%M%S")

# # Define a TensorBoard callback. Use the log_dir parameter
# # to specify the path to the directory where you want to save the
# # log files to be parsed by TensorBoard.
# tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir, histogram_freq=1)

# file_writer_cm = summary.create_file_writer(logdir + '/cm')


# def plot_to_image(figure):
#     """
#     Converts the matplotlib plot specified by 'figure' to a PNG image and
#     returns it. The supplied figure is closed and inaccessible after this call.
#     """

#     buf = io.BytesIO()

#     # Use plt.savefig to save the plot to a PNG in memory.
#     matplotlib.pyplot.savefig(buf, format='png')
#     # plt.show()

#     # Closing the figure prevents it from being displayed directly inside
#     # the notebook.
#     matplotlib.pyplot.close(figure)
#     buf.seek(0)

#     # Use tf.image.decode_png to convert the PNG buffer
#     # to a TF image. Make sure you use 4 channels.
#     image = image.decode_png(buf.getvalue(), channels=4)

#     # Use tf.expand_dims to add the batch dimension
#     image = expand_dims(image, 0)

#     return image


# def log_confusion_matrix(epoch, logs):
#     # Use the model to predict the values from the test_images.
#     test_pred_raw = model.predict(X_valid)

#     test_pred = np.argmax(test_pred_raw, axis=1)

#     test_labels = np.argmax(y_valid, axis=1)

#     # Calculate the confusion matrix using sklearn.metrics
#     cm = sklearn.metrics.confusion_matrix(test_labels, test_pred)

#     figure = plot_confusion_matrix(cm, class_names=TOP_EMOTIONS)
#     cm_image = plot_to_image(figure)

#     # Log the confusion matrix as an image summary.
#     with file_writer_cm.as_default():
#         summary.image("Confusion Matrix", cm_image, step=epoch)


# # Define the per-epoch callback.
# cm_callback = keras.callbacks.LambdaCallback(on_epoch_end=log_confusion_matrix)

# %%
callbacks = [
    early_stop, lr_scheduler
]

# %%
batch_size = 32
epochs = 150

INPUT_SHAPE = (3, 48, 48, 1)
optim = optimizers.Nadam(0.001)

model = memory_model(INPUT_SHAPE, num_class=5)
model.compile(
    loss='categorical_crossentropy',
    optimizer=optim,
    metrics=['accuracy']
)
# Out:
# Creating DenseNet
# #############################################
# Dense blocks: 5
# Layers per dense block: [6, 6, 6, 6, 6]
# #############################################
# Model: "convolutional_Bidrectional_LSTM"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 3, 256)            389808
# _________________________________________________________________
# bidirectional (Bidirectional (None, 3, 256)            394240
# _________________________________________________________________
# dropout_lstm_1 (Dropout)     (None, 3, 256)            0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               164352
# _________________________________________________________________
# dropout_lstm_2 (Dropout)     (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batchnorm_lstm_1 (BatchNorma (None, 128)               512
# _________________________________________________________________
# dropout_lstm_3 (Dropout)     (None, 128)               0
# _________________________________________________________________
# out_layer (Dense)            (None, 5)                 645
# =================================================================
# Total params: 966,069
# Trainable params: 956,293
# Non-trainable params: 9,776
# _________________________________________________________________

# %% [markdown]
# # Train network

# %%
history = model.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_valid, y_valid),
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    use_multiprocessing=True
)
# Out:
# Epoch 1/150
# 6/6 [==============================] - 61s 7s/step - loss: 3.6998 - accuracy: 0.2514 - val_loss: 2.1797 - val_accuracy: 0.2800
# Epoch 2/150
# 6/6 [==============================] - 40s 7s/step - loss: 3.4298 - accuracy: 0.3029 - val_loss: 2.1903 - val_accuracy: 0.1200
# Epoch 3/150
# 6/6 [==============================] - 40s 7s/step - loss: 3.3950 - accuracy: 0.2229 - val_loss: 2.2163 - val_accuracy: 0.1867
# Epoch 4/150
# 6/6 [==============================] - 40s 7s/step - loss: 3.0945 - accuracy: 0.3257 - val_loss: 2.3510 - val_accuracy: 0.1067
# Epoch 5/150
# 6/6 [==============================] - 40s 7s/step - loss: 3.2919 - accuracy: 0.2400 - val_loss: 2.3039 - val_accuracy: 0.1467
# Epoch 6/150
# 6/6 [==============================] - 39s 7s/step - loss: 2.8850 - accuracy: 0.3314 - val_loss: 2.3167 - val_accuracy: 0.1467
# Epoch 7/150
# 6/6 [==============================] - 40s 7s/step - loss: 3.1504 - accuracy: 0.3257 - val_loss: 2.2467 - val_accuracy: 0.2533
# Epoch 8/150
# 6/6 [==============================] - 40s 7s/step - loss: 2.7066 - accuracy: 0.3829 - val_loss: 2.2684 - val_accuracy: 0.2133
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 9/150
# 6/6 [==============================] - 40s 7s/step - loss: 2.7781 - accuracy: 0.3543 - val_loss: 2.4816 - val_accuracy: 0.2000
# Epoch 10/150
# 6/6 [==============================] - 40s 7s/step - loss: 2.6842 - accuracy: 0.4686 - val_loss: 2.5972 - val_accuracy: 0.2400
# Epoch 11/150
# 6/6 [==============================] - 40s 7s/step - loss: 2.5460 - accuracy: 0.4743 - val_loss: 2.2988 - val_accuracy: 0.2533
# Epoch 12/150
# 6/6 [==============================] - 40s 7s/step - loss: 2.0730 - accuracy: 0.5143 - val_loss: 2.1516 - val_accuracy: 0.3200
# Epoch 13/150
# 6/6 [==============================] - 40s 7s/step - loss: 2.2514 - accuracy: 0.5257 - val_loss: 2.5414 - val_accuracy: 0.1867
# Epoch 14/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.9652 - accuracy: 0.5714 - val_loss: 2.3904 - val_accuracy: 0.2667
# Epoch 15/150
# 6/6 [==============================] - 40s 7s/step - loss: 2.0221 - accuracy: 0.6000 - val_loss: 2.9037 - val_accuracy: 0.2400
# Epoch 16/150
# 6/6 [==============================] - 40s 7s/step - loss: 2.0337 - accuracy: 0.6286 - val_loss: 2.4823 - val_accuracy: 0.2667
# Epoch 17/150
# 6/6 [==============================] - 40s 7s/step - loss: 2.0183 - accuracy: 0.5771 - val_loss: 2.6125 - val_accuracy: 0.1733
# Epoch 18/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.7923 - accuracy: 0.6286 - val_loss: 2.5983 - val_accuracy: 0.2400
# Epoch 19/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.6745 - accuracy: 0.6171 - val_loss: 2.2187 - val_accuracy: 0.3333
# Epoch 20/150
# 6/6 [==============================] - 39s 7s/step - loss: 1.6003 - accuracy: 0.7086 - val_loss: 2.1815 - val_accuracy: 0.3600
# Epoch 21/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.7039 - accuracy: 0.6286 - val_loss: 2.4622 - val_accuracy: 0.2667
# Epoch 22/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.6401 - accuracy: 0.6000 - val_loss: 2.8386 - val_accuracy: 0.2400
# Epoch 23/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.5100 - accuracy: 0.6629 - val_loss: 2.8281 - val_accuracy: 0.1867
# Epoch 24/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.5816 - accuracy: 0.6686 - val_loss: 2.2007 - val_accuracy: 0.3867
# Epoch 25/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.5302 - accuracy: 0.6914 - val_loss: 2.3134 - val_accuracy: 0.5333
# Epoch 26/150
# 6/6 [==============================] - 39s 7s/step - loss: 1.5780 - accuracy: 0.6857 - val_loss: 2.9710 - val_accuracy: 0.3200
# Epoch 27/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.4239 - accuracy: 0.6971 - val_loss: 1.9551 - val_accuracy: 0.4533
# Epoch 28/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.4319 - accuracy: 0.6857 - val_loss: 2.4488 - val_accuracy: 0.3333
# Epoch 29/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.2657 - accuracy: 0.7486 - val_loss: 2.2367 - val_accuracy: 0.3867
# Epoch 30/150
# 6/6 [==============================] - 39s 7s/step - loss: 1.2634 - accuracy: 0.7771 - val_loss: 2.9574 - val_accuracy: 0.2933
# Epoch 31/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.3518 - accuracy: 0.7600 - val_loss: 2.3698 - val_accuracy: 0.3467
# Epoch 32/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.3096 - accuracy: 0.7143 - val_loss: 2.2258 - val_accuracy: 0.4533
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 33/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.1413 - accuracy: 0.7829 - val_loss: 2.8991 - val_accuracy: 0.2667
# Epoch 34/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.2368 - accuracy: 0.7371 - val_loss: 2.2426 - val_accuracy: 0.3733
# Epoch 35/150
# 6/6 [==============================] - 39s 7s/step - loss: 1.1038 - accuracy: 0.7886 - val_loss: 1.7980 - val_accuracy: 0.5467
# Epoch 36/150
# 6/6 [==============================] - 39s 7s/step - loss: 1.1869 - accuracy: 0.7714 - val_loss: 1.9200 - val_accuracy: 0.5333
# Epoch 37/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.1063 - accuracy: 0.7429 - val_loss: 1.7021 - val_accuracy: 0.5467
# Epoch 38/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.1223 - accuracy: 0.7543 - val_loss: 1.5092 - val_accuracy: 0.6533
# Epoch 39/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.0497 - accuracy: 0.8229 - val_loss: 1.7493 - val_accuracy: 0.5733
# Epoch 40/150
# 6/6 [==============================] - 39s 7s/step - loss: 1.0541 - accuracy: 0.8229 - val_loss: 1.2209 - val_accuracy: 0.7600
# Epoch 41/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.9902 - accuracy: 0.8457 - val_loss: 1.5033 - val_accuracy: 0.6667
# Epoch 42/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.1614 - accuracy: 0.7829 - val_loss: 1.4791 - val_accuracy: 0.6933
# Epoch 43/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.9734 - accuracy: 0.8514 - val_loss: 1.6580 - val_accuracy: 0.6133
# Epoch 44/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.9719 - accuracy: 0.8343 - val_loss: 1.3499 - val_accuracy: 0.7200
# Epoch 45/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.9344 - accuracy: 0.8514 - val_loss: 1.1709 - val_accuracy: 0.7467
# Epoch 46/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.9691 - accuracy: 0.8171 - val_loss: 1.2170 - val_accuracy: 0.7600
# Epoch 47/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.9379 - accuracy: 0.8400 - val_loss: 1.7017 - val_accuracy: 0.6667
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 48/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.1748 - accuracy: 0.8114 - val_loss: 1.2289 - val_accuracy: 0.7600
# Epoch 49/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.9739 - accuracy: 0.8286 - val_loss: 1.5250 - val_accuracy: 0.6667
# Epoch 50/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.9678 - accuracy: 0.8400 - val_loss: 1.1003 - val_accuracy: 0.7867
# Epoch 51/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.8362 - accuracy: 0.8857 - val_loss: 0.9983 - val_accuracy: 0.8267
# Epoch 52/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.8927 - accuracy: 0.8800 - val_loss: 1.3282 - val_accuracy: 0.7600
# Epoch 53/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.9482 - accuracy: 0.8571 - val_loss: 1.1199 - val_accuracy: 0.7867
# Epoch 54/150
# 6/6 [==============================] - 40s 7s/step - loss: 1.0388 - accuracy: 0.8286 - val_loss: 1.2737 - val_accuracy: 0.7067
# Epoch 55/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.9524 - accuracy: 0.8457 - val_loss: 1.9106 - val_accuracy: 0.6400
# Epoch 56/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.8735 - accuracy: 0.9086 - val_loss: 1.3556 - val_accuracy: 0.7600
# Epoch 57/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.8122 - accuracy: 0.8971 - val_loss: 1.0139 - val_accuracy: 0.8267
# Epoch 58/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.8400 - accuracy: 0.8629 - val_loss: 1.3725 - val_accuracy: 0.7200
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 59/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.8623 - accuracy: 0.8800 - val_loss: 1.0308 - val_accuracy: 0.8533
# Epoch 60/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.8852 - accuracy: 0.8857 - val_loss: 1.1590 - val_accuracy: 0.8133
# Epoch 61/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7731 - accuracy: 0.9314 - val_loss: 1.1194 - val_accuracy: 0.7467
# Epoch 62/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.8821 - accuracy: 0.9143 - val_loss: 1.3848 - val_accuracy: 0.7467
# Epoch 63/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.8086 - accuracy: 0.9143 - val_loss: 1.0944 - val_accuracy: 0.8533
# Epoch 64/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.7467 - accuracy: 0.8914 - val_loss: 1.0998 - val_accuracy: 0.7733
# Epoch 65/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7656 - accuracy: 0.9143 - val_loss: 1.0790 - val_accuracy: 0.8400
# Epoch 66/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.8125 - accuracy: 0.8914 - val_loss: 1.0195 - val_accuracy: 0.8133
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# Epoch 67/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7511 - accuracy: 0.9029 - val_loss: 1.1942 - val_accuracy: 0.7600
# Epoch 68/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.7680 - accuracy: 0.9143 - val_loss: 1.2471 - val_accuracy: 0.8000
# Epoch 69/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7792 - accuracy: 0.9200 - val_loss: 1.1541 - val_accuracy: 0.8133
# Epoch 70/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7133 - accuracy: 0.9486 - val_loss: 0.9986 - val_accuracy: 0.8400
# Epoch 71/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7329 - accuracy: 0.9314 - val_loss: 0.9818 - val_accuracy: 0.8800
# Epoch 72/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7601 - accuracy: 0.9429 - val_loss: 0.9361 - val_accuracy: 0.8533
# Epoch 73/150
# 6/6 [==============================] - 39s 6s/step - loss: 0.7338 - accuracy: 0.9371 - val_loss: 0.9614 - val_accuracy: 0.8533
# Epoch 74/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7211 - accuracy: 0.9429 - val_loss: 1.0617 - val_accuracy: 0.8267
# Epoch 75/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7381 - accuracy: 0.9314 - val_loss: 1.1646 - val_accuracy: 0.8133
# Epoch 76/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.7041 - accuracy: 0.9314 - val_loss: 1.2447 - val_accuracy: 0.7867
# Epoch 77/150
# 6/6 [==============================] - 39s 6s/step - loss: 0.7364 - accuracy: 0.9429 - val_loss: 1.2003 - val_accuracy: 0.7733
# Epoch 78/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7006 - accuracy: 0.9314 - val_loss: 0.9727 - val_accuracy: 0.8133
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# Epoch 79/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7396 - accuracy: 0.9429 - val_loss: 0.9752 - val_accuracy: 0.8267
# Epoch 80/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6613 - accuracy: 0.9714 - val_loss: 1.0366 - val_accuracy: 0.8400
# Epoch 81/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7129 - accuracy: 0.9371 - val_loss: 1.0266 - val_accuracy: 0.8533
# Epoch 82/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6694 - accuracy: 0.9486 - val_loss: 1.0655 - val_accuracy: 0.8400
# Epoch 83/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.7281 - accuracy: 0.9314 - val_loss: 1.1496 - val_accuracy: 0.7733
# Epoch 84/150
# 6/6 [==============================] - 41s 7s/step - loss: 0.6662 - accuracy: 0.9486 - val_loss: 1.0977 - val_accuracy: 0.8267
# Epoch 85/150
# 6/6 [==============================] - 42s 7s/step - loss: 0.6932 - accuracy: 0.9429 - val_loss: 1.2096 - val_accuracy: 0.8133
#
# Epoch 00085: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# Epoch 86/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6972 - accuracy: 0.9200 - val_loss: 1.1430 - val_accuracy: 0.8133
# Epoch 87/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6836 - accuracy: 0.9371 - val_loss: 1.1163 - val_accuracy: 0.8000
# Epoch 88/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.6860 - accuracy: 0.9486 - val_loss: 1.1730 - val_accuracy: 0.8400
# Epoch 89/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.6744 - accuracy: 0.9714 - val_loss: 1.0324 - val_accuracy: 0.8400
# Epoch 90/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.7184 - accuracy: 0.9371 - val_loss: 1.2565 - val_accuracy: 0.7733
# Epoch 91/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.7118 - accuracy: 0.9314 - val_loss: 1.0987 - val_accuracy: 0.7867
# Epoch 92/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6959 - accuracy: 0.9486 - val_loss: 1.0845 - val_accuracy: 0.8267
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# Epoch 93/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6723 - accuracy: 0.9543 - val_loss: 1.1133 - val_accuracy: 0.8000
# Epoch 94/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6705 - accuracy: 0.9486 - val_loss: 1.0603 - val_accuracy: 0.8133
# Epoch 95/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6516 - accuracy: 0.9657 - val_loss: 1.0699 - val_accuracy: 0.8267
# Epoch 96/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.6655 - accuracy: 0.9600 - val_loss: 1.0283 - val_accuracy: 0.8400
# Epoch 97/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6836 - accuracy: 0.9600 - val_loss: 1.0345 - val_accuracy: 0.8533
# Epoch 98/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.6961 - accuracy: 0.9429 - val_loss: 1.0358 - val_accuracy: 0.8533
# Epoch 99/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.6301 - accuracy: 0.9771 - val_loss: 1.0371 - val_accuracy: 0.8533
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# Epoch 100/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6432 - accuracy: 0.9600 - val_loss: 1.1413 - val_accuracy: 0.8400
# Epoch 101/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6538 - accuracy: 0.9657 - val_loss: 1.0832 - val_accuracy: 0.8400
# Epoch 102/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6513 - accuracy: 0.9657 - val_loss: 1.1057 - val_accuracy: 0.8400
# Epoch 103/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6126 - accuracy: 0.9943 - val_loss: 1.1396 - val_accuracy: 0.8267
# Epoch 104/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.7008 - accuracy: 0.9371 - val_loss: 1.0953 - val_accuracy: 0.8533
# Epoch 105/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6037 - accuracy: 0.9886 - val_loss: 0.9891 - val_accuracy: 0.8533
# Epoch 106/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6718 - accuracy: 0.9600 - val_loss: 1.1082 - val_accuracy: 0.8267
#
# Epoch 00106: ReduceLROnPlateau reducing learning rate to 0.00010737419361248613.
# Epoch 107/150
# 6/6 [==============================] - 42s 7s/step - loss: 0.6526 - accuracy: 0.9429 - val_loss: 1.0118 - val_accuracy: 0.8267
# Epoch 108/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6428 - accuracy: 0.9714 - val_loss: 1.0229 - val_accuracy: 0.8400
# Epoch 109/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6150 - accuracy: 0.9771 - val_loss: 1.1470 - val_accuracy: 0.7867
# Epoch 110/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6542 - accuracy: 0.9714 - val_loss: 1.1527 - val_accuracy: 0.8000
# Epoch 111/150
# 6/6 [==============================] - 39s 6s/step - loss: 0.6329 - accuracy: 0.9829 - val_loss: 1.0350 - val_accuracy: 0.8533
# Epoch 112/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.6657 - accuracy: 0.9600 - val_loss: 1.0379 - val_accuracy: 0.8400
# Epoch 113/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.6364 - accuracy: 0.9714 - val_loss: 1.0074 - val_accuracy: 0.8667
#
# Epoch 00113: ReduceLROnPlateau reducing learning rate to 8.589935605414213e-05.
# Epoch 114/150
# 6/6 [==============================] - 39s 6s/step - loss: 0.6247 - accuracy: 0.9829 - val_loss: 0.9871 - val_accuracy: 0.8533
# Epoch 115/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.6811 - accuracy: 0.9600 - val_loss: 0.9706 - val_accuracy: 0.8267
# Epoch 116/150
# 6/6 [==============================] - 39s 6s/step - loss: 0.6917 - accuracy: 0.9371 - val_loss: 1.0485 - val_accuracy: 0.8667
# Epoch 117/150
# 6/6 [==============================] - 39s 6s/step - loss: 0.6260 - accuracy: 0.9657 - val_loss: 1.1519 - val_accuracy: 0.8533
# Epoch 118/150
# 6/6 [==============================] - 39s 6s/step - loss: 0.5983 - accuracy: 0.9886 - val_loss: 1.2065 - val_accuracy: 0.8400
# Epoch 119/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6279 - accuracy: 0.9829 - val_loss: 1.2024 - val_accuracy: 0.8267
# Epoch 120/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6437 - accuracy: 0.9829 - val_loss: 1.1250 - val_accuracy: 0.8533
#
# Epoch 00120: ReduceLROnPlateau reducing learning rate to 6.871948717162013e-05.
# Epoch 121/150
# 6/6 [==============================] - 39s 6s/step - loss: 0.6491 - accuracy: 0.9829 - val_loss: 1.0144 - val_accuracy: 0.8800
# Epoch 122/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.6090 - accuracy: 0.9886 - val_loss: 1.0363 - val_accuracy: 0.8533
# Epoch 123/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.6552 - accuracy: 0.9600 - val_loss: 1.0462 - val_accuracy: 0.8267
# Epoch 124/150
# 6/6 [==============================] - 39s 6s/step - loss: 0.6135 - accuracy: 0.9829 - val_loss: 1.0416 - val_accuracy: 0.8400
# Epoch 125/150
# 6/6 [==============================] - 39s 7s/step - loss: 0.6308 - accuracy: 0.9771 - val_loss: 1.0249 - val_accuracy: 0.8400
# Epoch 126/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6274 - accuracy: 0.9771 - val_loss: 1.0016 - val_accuracy: 0.8533
# Epoch 127/150
# 6/6 [==============================] - 42s 7s/step - loss: 0.5994 - accuracy: 0.9886 - val_loss: 1.0738 - val_accuracy: 0.8133
#
# Epoch 00127: ReduceLROnPlateau reducing learning rate to 5.497558740898967e-05.
# Epoch 128/150
# 6/6 [==============================] - 41s 7s/step - loss: 0.6011 - accuracy: 0.9829 - val_loss: 1.1207 - val_accuracy: 0.8133
# Epoch 129/150
# 6/6 [==============================] - 42s 7s/step - loss: 0.5979 - accuracy: 0.9886 - val_loss: 1.1088 - val_accuracy: 0.8133
# Epoch 130/150
# 6/6 [==============================] - 43s 7s/step - loss: 0.6495 - accuracy: 0.9657 - val_loss: 1.0585 - val_accuracy: 0.8400
# Epoch 131/150
# 6/6 [==============================] - 43s 7s/step - loss: 0.6295 - accuracy: 0.9657 - val_loss: 1.1035 - val_accuracy: 0.8400
# Epoch 132/150
# 6/6 [==============================] - 43s 7s/step - loss: 0.6036 - accuracy: 0.9829 - val_loss: 1.0720 - val_accuracy: 0.8533
# Epoch 133/150
# 6/6 [==============================] - 43s 7s/step - loss: 0.6372 - accuracy: 0.9829 - val_loss: 1.0682 - val_accuracy: 0.8400
# Epoch 134/150
# 6/6 [==============================] - 42s 7s/step - loss: 0.6227 - accuracy: 0.9714 - val_loss: 1.1558 - val_accuracy: 0.8400
#
# Epoch 00134: ReduceLROnPlateau reducing learning rate to 4.398046876303852e-05.
# Epoch 135/150
# 6/6 [==============================] - 41s 7s/step - loss: 0.6141 - accuracy: 0.9771 - val_loss: 1.1358 - val_accuracy: 0.8400
# Epoch 136/150
# 6/6 [==============================] - 41s 7s/step - loss: 0.6090 - accuracy: 0.9943 - val_loss: 1.1055 - val_accuracy: 0.8400
# Epoch 137/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.5843 - accuracy: 0.9886 - val_loss: 1.1097 - val_accuracy: 0.8400
# Epoch 138/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.5918 - accuracy: 0.9886 - val_loss: 1.1191 - val_accuracy: 0.8400
# Epoch 139/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6000 - accuracy: 0.9886 - val_loss: 1.1386 - val_accuracy: 0.8267
# Epoch 140/150
# 6/6 [==============================] - 41s 7s/step - loss: 0.6485 - accuracy: 0.9771 - val_loss: 1.1732 - val_accuracy: 0.8267
# Epoch 141/150
# 6/6 [==============================] - 41s 7s/step - loss: 0.6198 - accuracy: 0.9600 - val_loss: 1.1627 - val_accuracy: 0.8400
#
# Epoch 00141: ReduceLROnPlateau reducing learning rate to 3.518437442835421e-05.
# Epoch 142/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6319 - accuracy: 0.9714 - val_loss: 1.1361 - val_accuracy: 0.8400
# Epoch 143/150
# 6/6 [==============================] - 41s 7s/step - loss: 0.5804 - accuracy: 0.9943 - val_loss: 1.1371 - val_accuracy: 0.8267
# Epoch 144/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.5937 - accuracy: 0.9943 - val_loss: 1.1685 - val_accuracy: 0.8267
# Epoch 145/150
# 6/6 [==============================] - 41s 7s/step - loss: 0.6860 - accuracy: 0.9543 - val_loss: 1.0920 - val_accuracy: 0.8400
# Epoch 146/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6487 - accuracy: 0.9714 - val_loss: 1.1111 - val_accuracy: 0.8400
# Epoch 147/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.5809 - accuracy: 0.9943 - val_loss: 1.1186 - val_accuracy: 0.8267
# Epoch 148/150
# 6/6 [==============================] - 41s 7s/step - loss: 0.5973 - accuracy: 0.9943 - val_loss: 1.1042 - val_accuracy: 0.8267
#
# Epoch 00148: ReduceLROnPlateau reducing learning rate to 2.8147498960606756e-05.
# Epoch 149/150
# 6/6 [==============================] - 41s 7s/step - loss: 0.5951 - accuracy: 0.9886 - val_loss: 1.0939 - val_accuracy: 0.8400
# Epoch 150/150
# 6/6 [==============================] - 40s 7s/step - loss: 0.6065 - accuracy: 0.9829 - val_loss: 1.1089 - val_accuracy: 0.8267

# %% [markdown]
# # Check results

# %% [markdown]
# Training and validation loss

# %%
history_dict = history.history

train_loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs_ = range(1, len(history_dict['accuracy']) + 1)

pyplot.plot(epochs_, train_loss_values, 'bo', label='Training loss')
pyplot.plot(epochs_, val_loss_values, 'b', label='Validation loss')
pyplot.title('Training and validation loss')
pyplot.xlabel('Epochs')
pyplot.ylabel('Loss')
pyplot.legend()
pyplot.show()

# %% [markdown]
# Training and validation accuracy

# %%
train_acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
pyplot.plot(epochs_, train_acc, 'bo', label='Training acc')
pyplot.plot(epochs_, val_acc, 'b', label='Validation acc')
pyplot.title('Training and validation accuracy')
pyplot.xlabel('Epochs')
pyplot.ylabel('Loss')
pyplot.legend()
pyplot.show()

# %% [markdown]
# Model architecture

# %%
keras.utils.plot_model(model, to_file='lstm_densenet_model.png', show_shapes=True)

# %% [markdown]
# Some examples from the set

# %%
np.random.seed(0)
indices = np.random.choice(range(X_valid.shape[0]), size=5, replace=False)

fig = pyplot.figure(1, (9, 30))

i = 0
for idx in indices:
    true_emotion = label_emotion_mapper[np.argmax(y_valid[idx])]
    pred_emotion = label_emotion_mapper[model.predict_classes(np.expand_dims(X_valid[idx], axis=0))[0]]

    for j in range(3):
        i += 1
        ax = pyplot.subplot(5, 3, i)
        sample_img = X_valid[idx, j, :, :, 0]
        ax.imshow(sample_img, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:{true_emotion}, p:{pred_emotion}")

pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %% [markdown]
# Confusion matrix

# %%
from sklearn.metrics import confusion_matrix

pred = model.predict(X_train)
pred=np.argmax(pred, axis=1)
y_test=np.argmax(y_train, axis=1)

conf = confusion_matrix(y_test, pred)

# %%
import seaborn as sns
ax=pyplot.subplot()

sns.heatmap(conf, annot=True, fmt='g', cmap='Blues', ax=ax)

ax.set_xlabel('Predicted labels');
ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(TOP_EMOTIONS);
ax.yaxis.set_ticklabels(TOP_EMOTIONS);

# %% [markdown]
# Model can be saved using the following command:
# ```
# from datetime import datetime
# model.save(datetime.now().strftime("%Y%m%d-%H%M%S") + "_" + str(epochs) + "_lstm_densenet_model_tf.h5")
# ```
#
# In order to convert H5 file to JSON, the following command can be used:
# ```
# tensorflowjs_converter --input_format=keras --output_format=tfjs_layers_model %file_name% %path_to_folder_to_save%
# ```
